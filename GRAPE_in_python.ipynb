# %%
import qutip as qt

# Create a spin-1/2 system tensor with a fockspace
cutoff = 10
g_zero = qt.tensor(qt.basis(2,0), qt.basis(cutoff, 0))

# %%
# !pip install qutip
# Out:
# ...
#   Using cached qutip-5.1.1-cp312-cp312-win_amd64.whl.metadata (9.4 kB)
# ...
#   Using cached numpy-2.2.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached scipy-1.15.2-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
# Using cached qutip-5.1.1-cp312-cp312-win_amd64.whl (9.8 MB)
# Using cached numpy-2.2.3-cp312-cp312-win_amd64.whl (12.6 MB)
# Using cached scipy-1.15.2-cp312-cp312-win_amd64.whl (40.9 MB)
# ...

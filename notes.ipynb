# %% [markdown]
# Write down filtered master equation with a classical drive coupled to the cavity field

# %% [markdown]
# Parameters for LevLab's cavity system
#
# $g_0 = 1.5$ MHz
#
# $N_A = 10^4$ to $10^6$
#
# $\Delta_A = 100$ GHz $= 100,000$ MHz
#
# $\omega_c = 5$ MHz to $100$ MHz
#
# $\omega_r = \frac{\hbar^2 c^2 k_0^2}{2 m_{Rb87}} = 0.05 MHz$

# %%
g_0 = 1.5
N_a_low = 10^4
N_a_high = 10^6
Δ_a = 100_000


E_0_low = g_0^2 * N_a_low/(4*Δ_a)
E_0_high = g_0^2 * N_a_high/(4*Δ_a)
println("E_0: ", E_0_low, " to ", E_0_high, " MHz")

ω_c_low = 5
ω_c_high = 100
ω_tilde_low =  ω_c_low/E_0_high
ω_tilde_high = ω_c_high/E_0_low
println("ω_tilde: ", ω_tilde_low, " to ", ω_tilde_high, " unitless")
# Out:
# E_0: 0.05625 to 5.625 MHz
# ω_tilde: 0.8888888888888888 to 1777.7777777777778 unitless

# %% [markdown]
# Add the Jacobian for the all momentum modes superradiance model including changes in driving field and P.

# %% [markdown]
# Technically, because the same noise drives the system and the observation, you need to modify the standard LQR theory. Figure that out.
